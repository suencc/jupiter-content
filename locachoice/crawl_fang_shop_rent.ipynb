# %%
# -*- coding:utf-8 -*-
import pymongo
import requests
import multiprocessing
from bs4 import BeautifulSoup
from time import sleep
import datetime
import random

'''
    本工程抓取房天下，广州天河区商铺出租信息
'''
def get_monggo_db():
    conn = pymongo.MongoClient('127.0.0.1',27017).locachoice
    conn.authenticate('locachoice','locachoice')
    return conn

def get_mongo_crawl_coll():
    conn = pymongo.MongoClient('127.0.0.1',27017).locachoice
    conn.authenticate('locachoice','locachoice')
    return conn['crawl_fang_shop_rent']

def clean_mongo_crawl_coll():
    db = get_monggo_db()
    re = db.drop_collection("crawl_fang_shop_rent")
    print(re)

# 请求天河商铺列表和url等基础信息
def req_tianhe_shop_list():
    base_url = 'http://shop.gz.fang.com/zu/house-a073/i3'
    coll = get_mongo_crawl_coll()
    for page_num in range(1, 13):
        page_url = '%s%d/' % (base_url, page_num)
        response = requests.get(page_url)
        html_doc = response.text        
        soup = BeautifulSoup(html_doc, 'html.parser', from_encoding = 'gb2312')
        shops = soup.find('div', class_='houseList').findAll('dl')
        for shop in shops:
            a_title = shop.find('p', class_ = 'title').find('a')
            url = 'http://shop.gz.fang.com%s' % a_title.get('href')
            title = a_title.get('title')
            p_mt15 = shop.find('p', class_ = 'gray6 mt15')            
            region = p_mt15.find('a').get('title')
            addr = p_mt15.find('span', class_ = 'iconAdress ml10 spAddr').get('title')
            desc = shop.find('p', class_ = 'gray6 mt10').text 
            area = shop.find('div', class_ = 'area area2 alignR').text
            price = shop.find('span', class_ = 'price').text
            doc = {
                'title': title,
                'url': url,
                'region': region,
                'addr': addr,
                'desc': desc,
                'area': area,
                'price': price
            }            
            coll.update_one({'url': url}, {'$set': doc}, True)
            print('one record')
    print('req_tianhe_sp_list, ended')

# 请求天河商铺信息，主要获取location
def req_tianhe_shop_info():
    coll = get_mongo_crawl_coll()
    cursor = coll.find({'lng': {'$exists': False}})
    for cur in cursor:
        try:
            print(cur.get('url'))
            html_doc = requests.get(cur.get('url')).text
            start = html_doc.find('<iframe frameborder=')
            start = html_doc.find('src=', start)
            start += 5
            end = html_doc.find('">',start)        
            map_url = html_doc[start:end]
            print(map_url)
            html_doc = requests.get(map_url).text
            start = html_doc.find('mapInfo')
            start = html_doc.find('px:', start)
            start += 4
            end = html_doc.find('",', start)
            lng = html_doc[start:end]
            print(lng)-
            start = html_doc.find('py:', start)
            start += 4
            end = html_doc.find('",', start)
            lat = html_doc[start:end]
            print(lat)
            start = html_doc.find('searchInfo', end)
            start += 11
            end = html_doc.find('}', start)
            end += 1
            searchinfo = html_doc[start:end]
            print(searchinfo)
            toset_doc = {
                'map_url': map_url,
                'lng': lng,
                'lat': lat,
                'searchinfo': searchinfo,
            }
            coll.update_one({'_id': cur.get('_id')}, {'$set': toset_doc}, False)
        except Exception as e:
            print(e)
    
if __name__ == '__main__':
#     req_tianhe_shop_list()
    req_tianhe_shop_info()
# Out:
# http://shop.gz.fang.com/zu/3_195075215.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2811992110&isrent=Y&width=678&height=355
# 113.32991790771484
# 23.147552490234375
# {district:"",comarea:"",projcode:"2811992110",projName:"广州国际贸易中心商铺"}
# http://shop.gz.fang.com/zu/3_197004347.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812220968&isrent=Y&width=678&height=355
# 113.33351135253906
# 23.136760711669922
# {district:"",comarea:"",projcode:"2812220968",projName:"天河南一路商铺"}
# http://shop.gz.fang.com/zu/3_197002877.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2811897110&isrent=Y&width=678&height=355
# 113.33512115478516
# 23.13348960876465
# {district:"",comarea:"",projcode:"2811897110",projName:"金泽大厦商铺"}
# http://shop.gz.fang.com/zu/3_197016588.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_197013516.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2811896800&isrent=Y&width=678&height=355
# 113.33606719970703
# 23.150495529174805
# {district:"",comarea:"",projcode:"2811896800",projName:"富力天河商务大厦商铺"}
# http://shop.gz.fang.com/zu/3_197947630.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812277786&isrent=Y&width=678&height=355
# 113.34017944335938
# 23.141651153564453
# {district:"",comarea:"",projcode:"2812277786",projName:"天河东路商铺"}
# http://shop.gz.fang.com/zu/3_194111756.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_199281644.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812058812&isrent=Y&width=678&height=355
# 113.3680419921875
# 23.139432907104492
# {district:"",comarea:"",projcode:"2812058812",projName:"东方都会广场商铺"}
# http://shop.gz.fang.com/zu/3_198155736.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198101977.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_196500831.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_197950771.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2811040194&isrent=Y&width=678&height=355
# 113.33293151855469
# 23.13857650756836
# {district:"",comarea:"",projcode:"2811040194",projName:"正佳广场"}
# http://shop.gz.fang.com/zu/3_195022904.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_199418990.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198870525.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198942803.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2811728180&isrent=Y&width=678&height=355
# 113.33264923095703
# 23.13007926940918
# {district:"",comarea:"",projcode:"2811728180",projName:"珠江新城西区商铺"}
# http://shop.gz.fang.com/zu/3_198912574.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812091002&isrent=Y&width=678&height=355
# 113.33758544921875
# 23.125797271728516
# {district:"",comarea:"",projcode:"2812091002",projName:"隽峰苑商铺"}
# http://shop.gz.fang.com/zu/3_199544590.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_199539247.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_199537033.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198802403.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198797164.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198818508.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198818077.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198815542.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198352783.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198432451.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812057794&isrent=Y&width=678&height=355
# 113.33983612060547
# 23.127260208129883
# {district:"",comarea:"",projcode:"2812057794",projName:"中海�Z晖华庭商铺"}
# http://shop.gz.fang.com/zu/3_198435848.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198437066.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_198106017.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812077566&isrent=Y&width=678&height=355
# 113.3379898071289
# 23.126405715942383
# {district:"",comarea:"",projcode:"2812077566",projName:"兴盛路步行街"}
# http://shop.gz.fang.com/zu/3_198065510.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2812077566&isrent=Y&width=678&height=355
# 113.3379898071289
# 23.126405715942383
# {district:"",comarea:"",projcode:"2812077566",projName:"兴盛路步行街"}
# http://shop.gz.fang.com/zu/3_198038888.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_197141310.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=2811728180&isrent=Y&width=678&height=355
# 113.33264923095703
# 23.13007926940918
# {district:"",comarea:"",projcode:"2811728180",projName:"珠江新城西区商铺"}
# http://shop.gz.fang.com/zu/3_199709161.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_199264558.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_197783591.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
# http://shop.gz.fang.com/zu/3_196008267.html
# http://esf.gz.fang.com/newsecond/map/NewMapDetail.aspx?newcode=0&isrent=Y&width=678&height=355
# 113.3415270
# 23.1270407
# {district:"",comarea:"",projcode:"0",projName:""}
