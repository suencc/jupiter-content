# %%
# -*- coding:utf-8 -*-
import pymongo
import requests
import multiprocessing
import re
import datetime
import random
import time  
import os  
import sched  

INTERVAL = 1800
# 初始化sched模块的scheduler类  
# 第一个参数是一个可以返回时间戳的函数，第二个参数可以在定时未到达之前阻塞。  
schedule = sched.scheduler(time.time, time.sleep)

def get_monggo_db():
    conn = pymongo.MongoClient('127.0.0.1',27017).locachoice
    conn.authenticate('locachoice', 'locachoice')
    return conn

def get_mongo_crawl_coll():
    conn = pymongo.MongoClient('127.0.0.1',27017).locachoice
    conn.authenticate('locachoice','locachoice')
    return conn['crawl_gzjt_gov'] 

def req_traffic_data():
    url_base = 'http://219.136.133.162/gztraffic/GetData.ashx?__r='    
    timeStamp = str(int(time.time()))
    url = url_base + timeStamp
    print(url)
    response  = requests.get(url)
    if response.status_code is not 200: return 404
    jdoc = response.json()
    roads = jdoc.get('RoadData')
    coll = get_mongo_crawl_coll 
    for road in roads:
        coll.insert_one(road)
    return 200

# 被周期性调度触发的函数  
def execute_command(cmd, inc):  
    ''''' 
    终端上显示当前计算机的连接情况 
    '''  
    print(cmd, inc)  
    schedule.enter(inc, 0, execute_command, (cmd, inc))  
  
  
def main(cmd, inc=1800):  
    # enter四个参数分别为：间隔事件、优先级（用于同时间到达的两个事件同时执行时定序）、被调用触发的函数，  
    # 给该触发函数的参数（tuple形式）  
    schedule.enter(0, 0, execute_command, (cmd, inc))  
    schedule.run()  
  
  
# 每60秒查看下网络连接情况  
if __name__ == '__main__':  
#     main("netstat -an", 10) 
    req_traffic_data()
# Out:
# http://219.136.133.162/gztraffic/GetData.ashx?__r=1497950347
# {'RoadID': 19, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '东风路', 'RoadSpeed': 33.81, 'RoadXCSJ': 948.9, 'RoadTTI': 1.52, 'CongIndex': 3.47, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 20, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '东风路', 'RoadSpeed': 34.4, 'RoadXCSJ': 941.03, 'RoadTTI': 1.56, 'CongIndex': 3.71, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 35, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '广州大道', 'RoadSpeed': 29.61, 'RoadXCSJ': 1175.39, 'RoadTTI': 1.73, 'CongIndex': 4.87, 'CongName': '轻度拥堵', 'Dir': '南-北', 'CssName': 'rank3'}
# {'RoadID': 36, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '广州大道', 'RoadSpeed': 31.72, 'RoadXCSJ': 1101.47, 'RoadTTI': 1.61, 'CongIndex': 4.07, 'CongName': '轻度拥堵', 'Dir': '北-南', 'CssName': 'rank3'}
# {'RoadID': 29, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '广园快速路', 'RoadSpeed': 50.58, 'RoadXCSJ': 1046.88, 'RoadTTI': 1.34, 'CongIndex': 2.3, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 30, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '广园快速路', 'RoadSpeed': 38.05, 'RoadXCSJ': 1208.34, 'RoadTTI': 1.64, 'CongIndex': 4.29, 'CongName': '轻度拥堵', 'Dir': '东-西', 'CssName': 'rank3'}
# {'RoadID': 1, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '江海大道-猎德路', 'RoadSpeed': 37.41, 'RoadXCSJ': 449.53, 'RoadTTI': 1.53, 'CongIndex': 3.56, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 2, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '江海大道-猎德路', 'RoadSpeed': 37.8, 'RoadXCSJ': 482.3, 'RoadTTI': 1.58, 'CongIndex': 3.87, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 53, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄埔大道西段', 'RoadSpeed': 23.44, 'RoadXCSJ': 1258.04, 'RoadTTI': 2.12, 'CongIndex': 7.44, 'CongName': '中度拥堵', 'Dir': '西-东', 'CssName': 'rank2'}
# {'RoadID': 54, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄埔大道西段', 'RoadSpeed': 25.26, 'RoadXCSJ': 1190.93, 'RoadTTI': 1.8, 'CongIndex': 5.34, 'CongName': '轻度拥堵', 'Dir': '东-西', 'CssName': 'rank3'}
# {'RoadID': 49, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '环市路', 'RoadSpeed': 23.77, 'RoadXCSJ': 1241.72, 'RoadTTI': 1.81, 'CongIndex': 5.41, 'CongName': '轻度拥堵', 'Dir': '西-东', 'CssName': 'rank3'}
# {'RoadID': 50, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '环市路', 'RoadSpeed': 30.15, 'RoadXCSJ': 997.39, 'RoadTTI': 1.43, 'CongIndex': 2.88, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 71, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '科韵路', 'RoadSpeed': 41.68, 'RoadXCSJ': 889.3, 'RoadTTI': 1.36, 'CongIndex': 2.38, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 72, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '科韵路', 'RoadSpeed': 43.18, 'RoadXCSJ': 857.36, 'RoadTTI': 1.32, 'CongIndex': 2.14, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 87, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '天河北路', 'RoadSpeed': 21.06, 'RoadXCSJ': 496.61, 'RoadTTI': 1.45, 'CongIndex': 2.98, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 88, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '天河北路', 'RoadSpeed': 18.74, 'RoadXCSJ': 618.42, 'RoadTTI': 1.63, 'CongIndex': 4.23, 'CongName': '轻度拥堵', 'Dir': '东-西', 'CssName': 'rank3'}
# {'RoadID': 59, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '机场路', 'RoadSpeed': 23.66, 'RoadXCSJ': 888.8, 'RoadTTI': 1.67, 'CongIndex': 4.49, 'CongName': '轻度拥堵', 'Dir': '南-北', 'CssName': 'rank3'}
# {'RoadID': 60, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '机场路', 'RoadSpeed': 23.96, 'RoadXCSJ': 888.21, 'RoadTTI': 1.62, 'CongIndex': 4.14, 'CongName': '轻度拥堵', 'Dir': '北-南', 'CssName': 'rank3'}
# {'RoadID': 41, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '工业大道', 'RoadSpeed': 27.03, 'RoadXCSJ': 892.76, 'RoadTTI': 1.29, 'CongIndex': 1.97, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 42, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '工业大道', 'RoadSpeed': 21.01, 'RoadXCSJ': 1149.43, 'RoadTTI': 1.73, 'CongIndex': 4.85, 'CongName': '轻度拥堵', 'Dir': '北-南', 'CssName': 'rank3'}
# {'RoadID': 63, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '解放路', 'RoadSpeed': 30.01, 'RoadXCSJ': 550.51, 'RoadTTI': 1.47, 'CongIndex': 3.16, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 64, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '解放路', 'RoadSpeed': 32.31, 'RoadXCSJ': 494.93, 'RoadTTI': 1.37, 'CongIndex': 2.48, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 99, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '新滘路', 'RoadSpeed': 43.19, 'RoadXCSJ': 907.75, 'RoadTTI': 1.27, 'CongIndex': 1.82, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 100, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '新滘路', 'RoadSpeed': 41.66, 'RoadXCSJ': 923.87, 'RoadTTI': 1.29, 'CongIndex': 1.96, 'CongName': '畅通', 'Dir': '东-西', 'CssName': 'rank5'}
# {'RoadID': 129, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '中山大道', 'RoadSpeed': 25.18, 'RoadXCSJ': 1736.98, 'RoadTTI': 1.48, 'CongIndex': 3.19, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 130, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '中山大道', 'RoadSpeed': 23.14, 'RoadXCSJ': 1883.05, 'RoadTTI': 1.53, 'CongIndex': 3.53, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 131, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '天河路', 'RoadSpeed': 23.09, 'RoadXCSJ': 585.74, 'RoadTTI': 1.75, 'CongIndex': 5.02, 'CongName': '轻度拥堵', 'Dir': '西-东', 'CssName': 'rank3'}
# {'RoadID': 132, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '
 'PublishTime': '/Date(1497950100000)/', 'RoadName': '体育东路-冼村路', 'RoadSpeed': 20.65, 'RoadXCSJ': 489.28, 'RoadTTI': 1.46, 'CongIndex': 3.04, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 86, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '体育东路-冼村路', 'RoadSpeed': 17.77, 'RoadXCSJ': 560.14, 'RoadTTI': 1.86, 'CongIndex': 5.73, 'CongName': '轻度拥堵', 'Dir': '北-南', 'CssName': 'rank3'}
# {'RoadID': 51, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄埔大道东段', 'RoadSpeed': 37.58, 'RoadXCSJ': 462.53, 'RoadTTI': 1.08, 'CongIndex': 0.56, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 52, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄埔大道东段', 'RoadSpeed': 31.24, 'RoadXCSJ': 549.28, 'RoadTTI': 1.22, 'CongIndex': 1.48, 'CongName': '畅通', 'Dir': '东-西', 'CssName': 'rank5'}
# {'RoadID': 73, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '临江大道', 'RoadSpeed': 35.9, 'RoadXCSJ': 614.59, 'RoadTTI': 1.28, 'CongIndex': 1.87, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 74, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '临江大道', 'RoadSpeed': 33.12, 'RoadXCSJ': 669.39, 'RoadTTI': 1.42, 'CongIndex': 2.77, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 121, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '内环路A线1', 'RoadSpeed': 39.71, 'RoadXCSJ': 886.76, 'RoadTTI': 1.63, 'CongIndex': 4.22, 'CongName': '轻度拥堵', 'Dir': '环线', 'CssName': 'rank3'}
# {'RoadID': 122, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '内环路A线2', 'RoadSpeed': 38.76, 'RoadXCSJ': 575.84, 'RoadTTI': 1.7, 'CongIndex': 4.66, 'CongName': '轻度拥堵', 'Dir': '环线', 'CssName': 'rank3'}
# {'RoadID': 123, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '内环路A线3', 'RoadSpeed': 47.68, 'RoadXCSJ': 544.56, 'RoadTTI': 1.4, 'CongIndex': 2.67, 'CongName': '基本畅通', 'Dir': '环线', 'CssName': 'rank4'}
# {'RoadID': 126, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '内环路B线3', 'RoadSpeed': 34.29, 'RoadXCSJ': 745.55, 'RoadTTI': 1.85, 'CongIndex': 5.66, 'CongName': '轻度拥堵', 'Dir': '环线', 'CssName': 'rank3'}
# {'RoadID': 125, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '内环路B线2', 'RoadSpeed': 40.51, 'RoadXCSJ': 592.8, 'RoadTTI': 1.56, 'CongIndex': 3.73, 'CongName': '基本畅通', 'Dir': '环线', 'CssName': 'rank4'}
# {'RoadID': 124, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '内环路B线1', 'RoadSpeed': 46.12, 'RoadXCSJ': 734.86, 'RoadTTI': 1.47, 'CongIndex': 3.11, 'CongName': '基本畅通', 'Dir': '环线', 'CssName': 'rank4'}
# {'RoadID': 31, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '广园西路', 'RoadSpeed': 24.33, 'RoadXCSJ': 171.48, 'RoadTTI': 2.12, 'CongIndex': 7.45, 'CongName': '中度拥堵', 'Dir': '南-北', 'CssName': 'rank2'}
# {'RoadID': 32, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '广园西路', 'RoadSpeed': 52.33, 'RoadXCSJ': 86.44, 'RoadTTI': 1, 'CongIndex': 0, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}
# {'RoadID': 81, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '三元里大道', 'RoadSpeed': 15.43, 'RoadXCSJ': 1140.56, 'RoadTTI': 2.08, 'CongIndex': 7.21, 'CongName': '中度拥堵', 'Dir': '南-北', 'CssName': 'rank2'}
# {'RoadID': 82, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '三元里大道', 'RoadSpeed': 19.65, 'RoadXCSJ': 832.03, 'RoadTTI': 1.5, 'CongIndex': 3.35, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 57, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄石路', 'RoadSpeed': 35.22, 'RoadXCSJ': 510.31, 'RoadTTI': 1.1, 'CongIndex': 0.7, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 58, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄石路', 'RoadSpeed': 20.79, 'RoadXCSJ': 879.9, 'RoadTTI': 1.76, 'CongIndex': 5.06, 'CongName': '轻度拥堵', 'Dir': '东-西', 'CssName': 'rank3'}
# {'RoadID': 5, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '白云大道', 'RoadSpeed': 32.81, 'RoadXCSJ': 1128.55, 'RoadTTI': 1.57, 'CongIndex': 3.82, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 6, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '白云大道', 'RoadSpeed': 22.43, 'RoadXCSJ': 1565.65, 'RoadTTI': 2.26, 'CongIndex': 8.07, 'CongName': '严重拥堵', 'Dir': '北-南', 'CssName': 'rank1'}
# {'RoadID': 69, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '康王路', 'RoadSpeed': 18.99, 'RoadXCSJ': 295.44, 'RoadTTI': 1.48, 'CongIndex': 3.23, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 70, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '康王路', 'RoadSpeed': 21.48, 'RoadXCSJ': 273.14, 'RoadTTI': 1.41, 'CongIndex': 2.75, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 79, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '人民路', 'RoadSpeed': 19.7, 'RoadXCSJ': 797.33, 'RoadTTI': 1.46, 'CongIndex': 3.03, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 80, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '人民路', 'RoadSpeed': 30.78, 'RoadXCSJ': 477.64, 'RoadTTI': 1.19, 'CongIndex': 1.29, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}
# {'RoadID': 75, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '南岸路-黄沙大道-六二三路', 'RoadSpeed': 27.84, 'RoadXCSJ': 611.72, 'RoadTTI': 1.3, 'CongIndex': 2.01, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 76, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '南岸路-黄沙大道-六二三路', 'RoadSpeed': 24.16, 'RoadXCSJ': 736.9, 'RoadTTI': 1.49, 'CongIndex': 3.26, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 91, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '西湾路—西槎路', 'RoadSpeed': 19.1, 'RoadXCSJ': 1248.58, 'RoadTTI': 1.5, 'CongIndex': 3.35, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 92, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '西湾路—西槎路', 'RoadSpeed': 22.25, 'RoadXCSJ': 1045.6, 'RoadTTI': 1.25, 'CongIndex': 1.64, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}
# {'RoadID': 119, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '增槎路—庆槎路', 'RoadSpeed': 38.49, 'RoadXCSJ': 493.99, 'RoadTTI': 1.3, 'CongIndex': 1.98, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 120, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '增槎路—庆槎路', 'RoadSpeed': 30.89, 'RoadXCSJ': 591.36, 'RoadTTI': 1.72, 'CongIndex': 4.81, 'CongName': '轻度拥堵', 'Dir': '北-南', 'CssName': 'rank3'}
# {'RoadID': 65, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '金沙洲路', 'RoadSpeed': 32.83, 'RoadXCSJ': 296.59, 'RoadTTI': 1.1, 'CongIndex': 0.67, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 66, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '金沙洲路', 'RoadSpeed': 28, 'RoadXCSJ': 350.02, 'RoadTTI': 1.49, 'CongIndex': 3.29, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 107, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '中山路', 'RoadSpeed': 17.13, 'RoadXCSJ': 1701.47, 'RoadTTI': 1.5, 'CongIndex': 3.31, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 108, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '中山路', 'RoadSpeed': 18.98, 'RoadXCSJ': 1536.14, 'RoadTTI': 1.43, 'CongIndex': 2.83, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 13, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '昌岗路-新港西', 'RoadSpeed': 24.92, 'RoadXCSJ': 831.76, 'RoadTTI': 1.38, 'CongIndex': 2.56, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 14, 'PublishTime': '/Date(1497950100000)/', 'RoadName':
 'PublishTime': '/Date(1497950100000)/', 'RoadName': '恒福路-永福路', 'RoadSpeed': 28.38, 'RoadXCSJ': 423.32, 'RoadTTI': 1.41, 'CongIndex': 2.71, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 11, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '仓边路-小北路-童心路-下塘西-景云路', 'RoadSpeed': 20.41, 'RoadXCSJ': 674.86, 'RoadTTI': 1.55, 'CongIndex': 3.69, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 12, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '仓边路-小北路-童心路-下塘西-景云路', 'RoadSpeed': 21.85, 'RoadXCSJ': 635.33, 'RoadTTI': 1.57, 'CongIndex': 3.81, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 93, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '先烈路-禺东西路', 'RoadSpeed': 24.48, 'RoadXCSJ': 784.69, 'RoadTTI': 1.29, 'CongIndex': 1.93, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 94, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '先烈路-禺东西路', 'RoadSpeed': 22.29, 'RoadXCSJ': 861.53, 'RoadTTI': 1.56, 'CongIndex': 3.73, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 7, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '宝岗大道', 'RoadSpeed': 27.49, 'RoadXCSJ': 491.87, 'RoadTTI': 1.01, 'CongIndex': 0.05, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 8, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '宝岗大道', 'RoadSpeed': 19.93, 'RoadXCSJ': 681.32, 'RoadTTI': 1.47, 'CongIndex': 3.15, 'CongName': '基本畅通', 'Dir': '北-南', 'CssName': 'rank4'}
# {'RoadID': 9, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '滨江路', 'RoadSpeed': 23.33, 'RoadXCSJ': 1178.57, 'RoadTTI': 1.47, 'CongIndex': 3.13, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 10, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '滨江路', 'RoadSpeed': 29.85, 'RoadXCSJ': 922.49, 'RoadTTI': 1.24, 'CongIndex': 1.61, 'CongName': '畅通', 'Dir': '东-西', 'CssName': 'rank5'}
# {'RoadID': 101, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '沿江路', 'RoadSpeed': 24.55, 'RoadXCSJ': 631.53, 'RoadTTI': 1.31, 'CongIndex': 2.06, 'CongName': '基本畅通', 'Dir': '西-东', 'CssName': 'rank4'}
# {'RoadID': 102, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '沿江路', 'RoadSpeed': 16.6, 'RoadXCSJ': 278.78, 'RoadTTI': 1.73, 'CongIndex': 4.88, 'CongName': '轻度拥堵', 'Dir': '东-西', 'CssName': 'rank3'}
# {'RoadID': 55, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄埔东路', 'RoadSpeed': 39.05, 'RoadXCSJ': 1106.91, 'RoadTTI': 1.02, 'CongIndex': 0.11, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 56, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '黄埔东路', 'RoadSpeed': 25.45, 'RoadXCSJ': 1695.34, 'RoadTTI': 1.48, 'CongIndex': 3.23, 'CongName': '基本畅通', 'Dir': '东-西', 'CssName': 'rank4'}
# {'RoadID': 111, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '开创大道', 'RoadSpeed': 40.89, 'RoadXCSJ': 1477.37, 'RoadTTI': 1.01, 'CongIndex': 0.09, 'CongName': '畅通', 'Dir': '西-东', 'CssName': 'rank5'}
# {'RoadID': 112, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '开创大道', 'RoadSpeed': 38.12, 'RoadXCSJ': 1537.77, 'RoadTTI': 1.04, 'CongIndex': 0.26, 'CongName': '畅通', 'Dir': '东-西', 'CssName': 'rank5'}
# {'RoadID': 15, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '车陂路', 'RoadSpeed': 20.5, 'RoadXCSJ': 412.7, 'RoadTTI': 1.26, 'CongIndex': 1.76, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 16, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '车陂路', 'RoadSpeed': 25, 'RoadXCSJ': 270.2, 'RoadTTI': 1.18, 'CongIndex': 1.23, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}
# {'RoadID': 17, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '大观路', 'RoadSpeed': 32.48, 'RoadXCSJ': 902.71, 'RoadTTI': 1.23, 'CongIndex': 1.54, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 18, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '大观路', 'RoadSpeed': 35.19, 'RoadXCSJ': 821.22, 'RoadTTI': 1.22, 'CongIndex': 1.46, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}
# {'RoadID': 25, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '丰乐路', 'RoadSpeed': 25.93, 'RoadXCSJ': 744.56, 'RoadTTI': 1.26, 'CongIndex': 1.76, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 26, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '丰乐路', 'RoadSpeed': 32.02, 'RoadXCSJ': 614.92, 'RoadTTI': 1.13, 'CongIndex': 0.89, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}
# {'RoadID': 115, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '大学城中环路', 'RoadSpeed': 31.45, 'RoadXCSJ': 1116.85, 'RoadTTI': 1.22, 'CongIndex': 1.48, 'CongName': '畅通', 'Dir': '环线', 'CssName': 'rank5'}
# {'RoadID': 116, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '大学城中环路', 'RoadSpeed': 30.84, 'RoadXCSJ': 1150.13, 'RoadTTI': 1.22, 'CongIndex': 1.43, 'CongName': '畅通', 'Dir': '环线', 'CssName': 'rank5'}
# {'RoadID': 127, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '东濠涌高架路', 'RoadSpeed': 34.39, 'RoadXCSJ': 244.72, 'RoadTTI': 1.35, 'CongIndex': 2.36, 'CongName': '基本畅通', 'Dir': '南-北', 'CssName': 'rank4'}
# {'RoadID': 128, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '东濠涌高架路', 'RoadSpeed': 26.23, 'RoadXCSJ': 325.02, 'RoadTTI': 1.97, 'CongIndex': 6.5, 'CongName': '中度拥堵', 'Dir': '北-南', 'CssName': 'rank2'}
# {'RoadID': 133, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '机场高速', 'RoadSpeed': 74.14, 'RoadXCSJ': 1141.17, 'RoadTTI': 1.14, 'CongIndex': 0.92, 'CongName': '畅通', 'Dir': '南-北', 'CssName': 'rank5'}
# {'RoadID': 134, 'PublishTime': '/Date(1497950100000)/', 'RoadName': '机场高速', 'RoadSpeed': 66.75, 'RoadXCSJ': 1322.88, 'RoadTTI': 1.23, 'CongIndex': 1.5, 'CongName': '畅通', 'Dir': '北-南', 'CssName': 'rank5'}

# %%
import sched 
import time 
schedule = sched.scheduler(time.time, time.sleep)  
print(time.time)
# Out:
# <built-in function time>

# %%
import time
# a = "2017-06-17 18:42:00"
# #中间过程，一般都需要将字符串转化为时间数组
# b = time.strptime(a,'%Y-%m-%d %H:%M:%S')
# print(b)
# #将"2011-09-28 10:00:00"转化为时间戳
# c = time.mktime(time.strptime(a,'%Y-%m-%d %H:%M:%S'))
# print(c)

# x = time.localtime(1497693600)
# time.strftime('%Y-%m-%d %H:%M:%S',x)
# type(time.localtime())

# print(time.time())
# print(time.localtime())

# timeArray = time.localtime()
# print(timeArray)
# otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
# timeStamp = int(time.mktime(timeArray))
# print(timeStamp)

# print(time.time())

# timeArray = time.localtime(timeStamp)
# otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
# print(otherStyleTime)

timeStamp = str(int(time.time()))
print(timeStamp)

otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
print(otherStyleTime)
